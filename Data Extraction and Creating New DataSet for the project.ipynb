# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('webmd.csv')

# %%
df.head(n=10)
# Out:
#           Age                      Condition        Date  \
# 0  75 or over                    Stuffy Nose   9/21/2014
# 1       25-34                  Cold Symptoms   1/13/2011
# 2       65-74                          Other   7/16/2012
# 3  75 or over                          Other   9/23/2010
# 4       35-44                          Other    1/6/2009
# 5       55-64                          Other   7/19/2008
# 6       25-34                  Birth Control   6/15/2017
# 7       45-54  Disease of Ovaries with Cysts   1/30/2017
# 8       25-34                           Acne   4/27/2016
# 9       55-64                    Stuffy Nose  10/29/2012
#
#                                       Drug  DrugId  EaseofUse  Effectiveness  \
# 0                             25dph-7.5peh  146724          5              5
# 1                             25dph-7.5peh  146724          5              5
# 2             warfarin (bulk) 100 % powder  144731          2              3
# ...

# %%
df=df[['Drug','Age','Sex','Condition','Sides']]

# %%
df.head(n=10)
# Out:
#                                       Drug         Age     Sex  \
# 0                             25dph-7.5peh  75 or over    Male
# 1                             25dph-7.5peh       25-34  Female
# 2             warfarin (bulk) 100 % powder       65-74  Female
# 3             warfarin (bulk) 100 % powder  75 or over  Female
# 4             warfarin (bulk) 100 % powder       35-44    Male
# 5             warfarin (bulk) 100 % powder       55-64    Male
# 6                                wymzya fe       25-34  Female
# 7                                wymzya fe       45-54  Female
# 8                                wymzya fe       25-34  Female
# 9  12 hour nasal relief spray, non-aerosol       55-64    Male
#
#                        Condition  \
# 0                    Stuffy Nose
# 1                  Cold Symptoms
# 2                          Other
# 3                          Other
# 4                          Other
# 5                          Other
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362806 entries, 0 to 362805
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Drug       362806 non-null  object
#  1   Age        362806 non-null  object
#  2   Sex        362806 non-null  object
#  3   Condition  362806 non-null  object
#  4   Sides      362806 non-null  object
# dtypes: object(5)
# memory usage: 13.8+ MB

# %%
df[df==' ']=np.nan

# %%
df.head(n=15)
# Out:
#                                        Drug         Age     Sex  \
# 0                              25dph-7.5peh  75 or over    Male
# 1                              25dph-7.5peh       25-34  Female
# 2              warfarin (bulk) 100 % powder       65-74  Female
# 3              warfarin (bulk) 100 % powder  75 or over  Female
# 4              warfarin (bulk) 100 % powder       35-44    Male
# 5              warfarin (bulk) 100 % powder       55-64    Male
# 6                                 wymzya fe       25-34  Female
# 7                                 wymzya fe       45-54  Female
# 8                                 wymzya fe       25-34  Female
# 9   12 hour nasal relief spray, non-aerosol       55-64    Male
# 10                      pyrogallol crystals       65-74    Male
# 11                                     lyza       19-24     NaN
# 12                                     lyza         NaN  Female
# 13                                     lyza       19-24  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362806 entries, 0 to 362805
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Drug       362806 non-null  object
#  1   Age        350604 non-null  object
#  2   Sex        336269 non-null  object
#  3   Condition  362763 non-null  object
#  4   Sides      345346 non-null  object
# dtypes: object(5)
# memory usage: 13.8+ MB

# %%
df=df.dropna()

# %%
df.head(n=20)
# Out:
#                                        Drug         Age     Sex  \
# 0                              25dph-7.5peh  75 or over    Male
# 1                              25dph-7.5peh       25-34  Female
# 6                                 wymzya fe       25-34  Female
# 7                                 wymzya fe       45-54  Female
# 8                                 wymzya fe       25-34  Female
# 9   12 hour nasal relief spray, non-aerosol       55-64    Male
# 13                                     lyza       19-24  Female
# 16                                     lyza       25-34  Female
# 18                                     lyza       25-34  Female
# 19                                     lyza       25-34  Female
# 21                                     lyza       25-34  Female
# 23                                     lyza       25-34  Female
# 25                                     lyza       25-34  Female
# 26                                     lyza       35-44  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 315605 entries, 0 to 362805
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Drug       315605 non-null  object
#  1   Age        315605 non-null  object
#  2   Sex        315605 non-null  object
#  3   Condition  315605 non-null  object
#  4   Sides      315605 non-null  object
# dtypes: object(5)
# memory usage: 14.4+ MB

# %%
print(df['Drug'].nunique())
print(df['Age'].nunique())
print(df['Sex'].nunique())
print(df['Condition'].nunique())
print(df['Sides'].nunique())
# Out:
# 5278
# 11
# 2
# 1640
# 1617

# %%
df.to_csv('Extracted data.csv')
